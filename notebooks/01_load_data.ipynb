# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import sys
sys.path.append("..")

# %%
# Reading in dataset of recipes by ingredients
# Reference: https://www.kaggle.com/datasets/alincijov/cooking-ingredients?select=train.csv

# Loading in the dataset
df = pd.read_csv('../data/recipes_by_ingredients.csv', index_col = 0)
df
# Out:
#                                 achiote paste  achiote powder  acini di pepe  \
# label
# Infineon Raceway Baked Beans              0.0             0.0            0.0
# Sour Cream Noodle Bake                    0.0             0.0            0.0
# Middle-Eastern Eggplant Rounds            0.0             0.0            0.0
# Saffron Jewel Rice                        0.0             0.0            0.0
# Thai Sweet and Sour Wings                 0.0             0.0            0.0
# ...                                       ...             ...            ...
# Spicy Agave Wave                          0.0             0.0            0.0
# Apple Chimichangas                        0.0             0.0            0.0
# Summer Corn Salad                         0.0             0.0            0.0
# Zucchini Stuffed Tomatoes                 0.0             0.0            0.0
# Crabby Bisque                             0.0             0.0            0.0
#
#                                 acorn squash  active dry yeast  adobo sauce  \
# label
# Infineon Raceway Baked Beans             0.0               0.0          0.0
# Sour Cream Noodle Bake                   0.0               0.0          0.0
# Middle-Eastern Eggplant Rounds           0.0               0.0          0.0
# Saffron Jewel Rice                       0.0               0.0          0.0
# Thai Sweet and Sour Wings                0.0               0.0          0.0
# ...                                      ...               ...          ...
# Spicy Agave Wave                         0.0               0.0          0.0
# Apple Chimichangas                       0.0               0.0          0.0
# Summer Corn Salad                        0.0               0.0          0.0
# Zucchini Stuffed Tomatoes                0.0               0.0          0.0
# Crabby Bisque                            0.0               0.0          0.0
#
#                                 adobo seasoning  adzuki beans  agave nectar  \
# label
# Infineon Raceway Baked Beans                0.0           0.0           0.0
# Sour Cream Noodle Bake                      0.0           0.0           0.0
# Middle-Eastern Eggplant Rounds              0.0           0.0           0.0
# Saffron Jewel Rice                          0.0           0.0           0.0
# Thai Sweet and Sour Wings                   0.0           0.0           0.0
# ...                                         ...           ...           ...
# Spicy Agave Wave                            0.0           0.0           1.0
# Apple Chimichangas                          0.0           0.0           0.0
# Summer Corn Salad                           0.0           0.0           0.0
# Zucchini Stuffed Tomatoes                   0.0           0.0           0.0
# Crabby Bisque                               0.0           0.0           0.0
#
#                                 agave tequila  ...  yellow rock sugar  \
# label                                          ...
# Infineon Raceway Baked Beans              0.0  ...                0.0
# Sour Cream Noodle Bake                    0.0  ...                0.0
# Middle-Eastern Eggplant Rounds            0.0  ...                0.0
# Saffron Jewel Rice                        0.0  ...                0.0
# Thai Sweet and Sour Wings                 0.0  ...                0.0
# ...                                       ...  ...                ...
# Spicy Agave Wave                          0.0  ...                0.0
# Apple Chimichangas                        0.0  ...                0.0
# Summer Corn Salad                         0.0  ...                0.0
# Zucchini Stuffed Tomatoes                 0.0  ...                0.0
# Crabby Bisque                             0.0  ...                0.0
#
#                                 yellow squash  yellow summer squash  \
# label
# Infineon Raceway Baked Beans              0.0                   0.0
# Sour Cream Noodle Bake                    0.0                   0.0
# Middle-Eastern Eggplant Rounds            0.0                   0.0
# Saffron Jewel Rice                        0.0                   0.0
# Thai Sweet and Sour Wings                 0.0                   0.0
# ...                                       ...                   ...
# Spicy Agave Wave                          0.0                   0.0
# Apple Chimichangas                        0.0                   0.0
# Summer Corn Salad                         0.0                   0.0
# Zucchini Stuffed Tomatoes                 0.0                   0.0
# Crabby Bisque                             0.0                   0.0
#
#                                 yellow tomato  yellowfin tuna  yogurt cheese  \
# label
# Infineon Raceway Baked Beans              0.0             0.0            0.0
# Sour Cream Noodle Bake                    0.0             0.0            0.0
# Middle-Eastern Eggplant Rounds            0.0             0.0            0.0
# Saffron Jewel Rice                        0.0             0.0            0.0
# Thai Sweet and Sour Wings                 0.0             0.0            0.0
# ...                                       ...             ...            ...
# Spicy Agave Wave                          0.0             0.0            0.0
# Apple Chimichangas                        0.0             0.0            0.0
# Summer Corn Salad                         0.0             0.0            0.0
# Zucchini Stuffed Tomatoes                 0.0             0.0            0.0
# Crabby Bisque                             0.0             0.0            0.0
#
#                                 yucca root  yukon gold potatoes  yuzu juice  \
# label
# Infineon Raceway Baked Beans           0.0                  0.0         0.0
# Sour Cream Noodle Bake                 0.0                  0.0         0.0
# Middle-Eastern Eggplant Rounds         0.0                  0.0         0.0
# Saffron Jewel Rice                     0.0                  0.0         0.0
# Thai Sweet and Sour Wings              0.0                  0.0         0.0
# ...                                    ...                  ...         ...
# Spicy Agave Wave                       0.0                  0.0         0.0
# Apple Chimichangas                     0.0                  0.0         0.0
# Summer Corn Salad                      0.0                  0.0         0.0
# Zucchini Stuffed Tomatoes              0.0                  0.0         0.0
# Crabby Bisque                          0.0                  0.0         0.0
#
#                                 zucchini blossoms
# label
# Infineon Raceway Baked Beans                  0.0
# Sour Cream Noodle Bake                        0.0
# Middle-Eastern Eggplant Rounds                0.0
# Saffron Jewel Rice                            0.0
# Thai Sweet and Sour Wings                     0.0
# ...                                           ...
# Spicy Agave Wave                              0.0
# Apple Chimichangas                            0.0
# Summer Corn Salad                             0.0
# Zucchini Stuffed Tomatoes                     0.0
# Crabby Bisque                                 0.0
#
# [29183 rows x 2924 columns]

# %%
df = df.astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29183 entries, Infineon Raceway Baked Beans to Crabby Bisque
# Columns: 2924 entries, achiote paste to zucchini blossoms
# dtypes: int64(2924)
# memory usage: 651.2+ MB

# %%
most_used = pd.DataFrame(df.sum(axis=0).sort_values(ascending=False))
most_used.head(10)
# Out:
#                            0
# ground black pepper     8996
# unsalted butter         5746
# all-purpose flour       5233
# olive oil               4936
# extra-virgin olive oil  4343
# kosher salt             3733
# heavy cream             2602
# large eggs              2595
# vegetable oil           2034
# vanilla extract         2022

# %%
# Count how many recipes use each ingredient
usage_counts = (df == 1).sum(axis=0)

plt.figure(figsize=(10,6))
sns.histplot(usage_counts, bins=200)   # choose bins as you prefer

plt.title("Distribution of Ingredient Usage Across Recipes")
plt.xlabel("Number of Recipes an Ingredient Appears In")
plt.ylabel("Number of Ingredients")
plt.tight_layout()
plt.show()
